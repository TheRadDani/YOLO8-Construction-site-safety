# %% [markdown]
# <a href="https://colab.research.google.com/github/TheRadDani/YOLO8-Construction-site-safety/blob/main/Yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("roboflow-universe-projects").project("construction-site-safety")
dataset = project.version(30).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.107, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Construction-Site-Safety-30 in yolov8:: 100%|██████████| 1446/1446 [00:00<00:00, 4910.81it/s]

# %%
# %%bash
# folder_name="Datasets"
# if [ ! -d "$folder_name" ]; then
#     mkdir "$folder_name"
#     echo "Folder created: $folder_name"
# else
#     echo "Folder already exists: $folder_name"
# fi
# Out:
# Folder already exists: Datasets

# %%
# !mv Construction-Site-Safety-30 Datasets

# %%
# !nvidia-smi
# Out:
# Wed May 24 02:18:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.4/589.4 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 27.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:01<00:00, 55.1MB/s]
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients
#
# ...
# 100% 476k/476k [00:00<00:00, 38.5MB/s]
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 68.0ms
# Speed: 12.9ms preprocess, 68.0ms inference, 37.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/Datasets/Construction-Site-Safety-30/data.yaml' epochs = 50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
